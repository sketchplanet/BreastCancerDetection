# %% [markdown]
# ## 依赖

# %%
import keras
import pandas as pd
from glob import glob
import os
import cv2
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline

preprocess_path = "./input/"
classes_num = 2
img_height = 299
img_width = 299
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 均衡样本

# %%
import random
tumor_files = glob(os.path.join(preprocess_path,"tumor/*jpg"))
normal_files = np.random.choice(glob(os.path.join(preprocess_path, "normal/*jpg")),len(tumor_files))
train_files = list(tumor_files) + list(normal_files)
random.shuffle(train_files)

# %% [markdown]
# ## 数据增强

# %%
import imgaug as ia
from imgaug import augmenters as iaa

seq = iaa.Sequential(
    [
        iaa.Fliplr(0.5), # horizontally flip with probability 0.5
    
        iaa.Affine(
            scale=(1, 1.1),
            rotate=90*np.random.choice([1,2,3]), # rotate by -180 to +180 degrees
        ),
    ],
    random_order=True
)

# %%
def show_augmented_images(img_file):
    img = cv2.imread(img_file)
    imgs = [img] + seq.augment_images([img for x in range(4)])

    plt.figure(figsize=(16, 6))
    for i in range(0, 4):
        plt.subplot(1, 4, i + 1)
        plt.imshow(imgs[i])
        
show_augmented_images(train_files[0])
#show_augmented_images(train_files[1])
#show_augmented_images(train_files[2])
#show_augmented_images(train_files[3])

# %%
#tumor 1 normal 0
def get_level(path):
    if(path.split('/')[2]=='tumor'):
        return 1
    elif(path.split('/')[2]=='normal'):
        return 0
    else:
        return None
    


# Example: 1 -> [0, 1]
def get_onehot(level):
    level_vec = np.zeros(classes_num)
    level_vec[level] = 1
    
    return level_vec

# %%
from keras.utils.data_utils import Sequence

class DataSequence(Sequence):
    def __init__(self, file_list, batch_size, augment=False):
        self.file_list = file_list
        self.batch_size = batch_size
        self.augment = augment

    def __len__(self):
        return len(self.file_list) // self.batch_size

    def __getitem__(self, idx):
        imgs = []
        labels = []
        
        i = idx * self.batch_size
        
        while len(imgs) < self.batch_size:
            file = self.file_list[i]
            
            level = get_level(file)
            if level is None:
                print("missing level: " + file)
                i += 1
                continue
            
            img = cv2.imread(file)
            
            if img is not None:
                imgs.append(img)
                labels.append(get_onehot(level))
                #class_weights = get_class_weights(current_epoch)

            i += 1

        # Image augmentation
        if self.augment:
            imgs = seq.augment_images(imgs)

        return np.asarray(imgs).astype(np.float16), np.asarray(labels).astype(np.int8)

# %% [markdown]
# ## 网络结构

# %%
from keras.models import Model
from keras.optimizers import Adam
from keras.applications.inception_v3 import InceptionV3
from keras.layers import Dense, Input, Flatten, Dropout, GlobalAveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

img_channels = 3
img_dim = (img_height, img_width, img_channels)
from datetime import datetime as dt
def get_experiment_id():
    time_str = dt.now().strftime('%Y-%m-%d-%H-%M-%S')
    experiment_id = 'Inceptin_{}'.format(time_str)

    return experiment_id
def inceptionv3(img_dim=img_dim):
    input_tensor = Input(shape=img_dim)
    base_model = InceptionV3(include_top=False,
                   weights='imagenet',
                   input_shape=img_dim)
    bn = BatchNormalization()(input_tensor)
    x = base_model(bn)
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)
    output = Dense(classes_num, activation='softmax')(x)
    model = Model(input_tensor, output)
    return model

model = inceptionv3()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 299, 299, 3)       0
# _________________________________________________________________
# batch_normalization_95 (Batc (None, 299, 299, 3)       12
# _________________________________________________________________
# inception_v3 (Model)         (None, 8, 8, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 4098
# =================================================================
# Total params: 21,806,894
# Trainable params: 21,772,456
# Non-trainable params: 34,438
# _________________________________________________________________

# %% [markdown]
# ## 训练集测试集划分

# %%
n_val_files = len(train_files) // 10
val_file_list = train_files[:n_val_files]
train_file_list = train_files[n_val_files:]

# %% [markdown]
# ## 训练过程

# %%
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
batch_size = 16

train_gen = DataSequence(train_file_list, batch_size, augment=True)
validate_gen = DataSequence(val_file_list, batch_size, augment=True)
#use multigpu 8
#model.compile(optimizer=Adam(lr=1e-4), loss='categorical_crossentropy', metrics = ['accuracy'])
#parallel_model.compile(optimizer=Adam(lr=1e-4), loss='categorical_crossentropy', metrics = ['accuracy'])
model.compile(loss='categorical_crossentropy', optimizer=SGD(lr=0.003, momentum=0.9, nesterov=True), metrics=['accuracy'])
experiment_id = get_experiment_id()

callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, verbose=1),
    ModelCheckpoint("inceptionV3_sgd"+".hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='auto'),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=7, verbose=1, mode='auto', epsilon=0.01, cooldown=0, min_lr=1e-6)
]

history = model.fit_generator(generator=train_gen, 
                              validation_data=validate_gen,
                              steps_per_epoch=(len(train_gen)//10),
                              validation_steps=len(validate_gen),
                              verbose=1,
                              epochs=50,
                              callbacks=callbacks,
                              workers=12, # recommend: number of cpu cores
                              use_multiprocessing=True)
# Out:
# Epoch 1/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.3016 - acc: 0.8709Epoch 00001: val_loss improved from inf to 0.26906, saving model to inceptionV3_sgd.hdf5
# 352/352 [==============================] - 257s 730ms/step - loss: 0.3009 - acc: 0.8713 - val_loss: 0.2691 - val_acc: 0.9090
# Epoch 2/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.1873 - acc: 0.9257Epoch 00002: val_loss improved from 0.26906 to 0.16645, saving model to inceptionV3_sgd.hdf5
# 352/352 [==============================] - 245s 696ms/step - loss: 0.1870 - acc: 0.9258 - val_loss: 0.1665 - val_acc: 0.9423
# Epoch 3/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.1578 - acc: 0.9430Epoch 00003: val_loss improved from 0.16645 to 0.12487, saving model to inceptionV3_sgd.hdf5
# 352/352 [==============================] - 243s 689ms/step - loss: 0.1575 - acc: 0.9432 - val_loss: 0.1249 - val_acc: 0.9565
# Epoch 4/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.1678 - acc: 0.9427Epoch 00004: val_loss did not improve
# 352/352 [==============================] - 242s 689ms/step - loss: 0.1675 - acc: 0.9426 - val_loss: 0.1334 - val_acc: 0.9469
# Epoch 5/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.1331 - acc: 0.9500Epoch 00005: val_loss improved from 0.12487 to 0.11400, saving model to inceptionV3_sgd.hdf5
# 352/352 [==============================] - 245s 697ms/step - loss: 0.1329 - acc: 0.9499 - val_loss: 0.1140 - val_acc: 0.9588
# Epoch 6/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.1245 - acc: 0.9553Epoch 00006: val_loss improved from 0.11400 to 0.09430, saving model to inceptionV3_sgd.hdf5
# 352/352 [==============================] - 244s 694ms/step - loss: 0.1242 - acc: 0.9554 - val_loss: 0.0943 - val_acc: 0.9688
# Epoch 7/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.1613 - acc: 0.9459Epoch 00007: val_loss did not improve
# 352/352 [==============================] - 245s 695ms/step - loss: 0.1610 - acc: 0.9460 - val_loss: 0.1339 - val_acc: 0.9487
# Epoch 8/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.1180 - acc: 0.9574Epoch 00008: val_loss did not improve
# 352/352 [==============================] - 243s 691ms/step - loss: 0.1187 - acc: 0.9572 - val_loss: 0.1169 - val_acc: 0.9551
# Epoch 9/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.1037 - acc: 0.9642Epoch 00009: val_loss did not improve
# 352/352 [==============================] - 245s 696ms/step - loss: 0.1043 - acc: 0.9640 - val_loss: 0.0967 - val_acc: 0.9639
# Epoch 10/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.1150 - acc: 0.9590Epoch 00010: val_loss did not improve
# 352/352 [==============================] - 245s 695ms/step - loss: 0.1149 - acc: 0.9590 - val_loss: 0.0956 - val_acc: 0.9661
# Epoch 11/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0862 - acc: 0.9683Epoch 00011: val_loss improved from 0.09430 to 0.08101, saving model to inceptionV3_sgd.hdf5
# 352/352 [==============================] - 245s 696ms/step - loss: 0.0864 - acc: 0.9682 - val_loss: 0.0810 - val_acc: 0.9711
# Epoch 12/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0817 - acc: 0.9717Epoch 00012: val_loss did not improve
# 352/352 [==============================] - 244s 694ms/step - loss: 0.0820 - acc: 0.9716 - val_loss: 0.1239 - val_acc: 0.9591
# Epoch 13/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0897 - acc: 0.9683Epoch 00013: val_loss did not improve
# 352/352 [==============================] - 244s 693ms/step - loss: 0.0895 - acc: 0.9684 - val_loss: 0.0897 - val_acc: 0.9704
# Epoch 14/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0902 - acc: 0.9687Epoch 00014: val_loss did not improve
# 352/352 [==============================] - 245s 697ms/step - loss: 0.0901 - acc: 0.9688 - val_loss: 0.1296 - val_acc: 0.9540
# Epoch 15/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0757 - acc: 0.9736Epoch 00015: val_loss did not improve
# 352/352 [==============================] - 245s 697ms/step - loss: 0.0755 - acc: 0.9737 - val_loss: 0.1154 - val_acc: 0.9605
# Epoch 16/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0739 - acc: 0.9749Epoch 00016: val_loss did not improve
# 352/352 [==============================] - 245s 695ms/step - loss: 0.0740 - acc: 0.9748 - val_loss: 0.1165 - val_acc: 0.9562
# Epoch 17/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0802 - acc: 0.9728Epoch 00017: val_loss did not improve
# 352/352 [==============================] - 244s 693ms/step - loss: 0.0800 - acc: 0.9728 - val_loss: 0.0817 - val_acc: 0.9707
# Epoch 18/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0986 - acc: 0.9678Epoch 00018: val_loss improved from 0.08101 to 0.06705, saving model to inceptionV3_sgd.hdf5
# 352/352 [==============================] - 245s 697ms/step - loss: 0.0986 - acc: 0.9677 - val_loss: 0.0670 - val_acc: 0.9778
# Epoch 19/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0801 - acc: 0.9715Epoch 00019: val_loss improved from 0.06705 to 0.06293, saving model to inceptionV3_sgd.hdf5
# 352/352 [==============================] - 244s 694ms/step - loss: 0.0802 - acc: 0.9714 - val_loss: 0.0629 - val_acc: 0.9776
# Epoch 20/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0692 - acc: 0.9756Epoch 00020: val_loss improved from 0.06293 to 0.06028, saving model to inceptionV3_sgd.hdf5
# 352/352 [==============================] - 243s 691ms/step - loss: 0.0692 - acc: 0.9755 - val_loss: 0.0603 - val_acc: 0.9791
# Epoch 21/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0577 - acc: 0.9770Epoch 00021: val_loss did not improve
# 352/352 [==============================] - 244s 693ms/step - loss: 0.0576 - acc: 0.9771 - val_loss: 0.0616 - val_acc: 0.9768
# Epoch 22/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0441 - acc: 0.9845Epoch 00022: val_loss improved from 0.06028 to 0.05501, saving model to inceptionV3_sgd.hdf5
# 352/352 [==============================] - 245s 697ms/step - loss: 0.0440 - acc: 0.9846 - val_loss: 0.0550 - val_acc: 0.9811
# Epoch 23/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0562 - acc: 0.9781Epoch 00023: val_loss did not improve
# 352/352 [==============================] - 245s 696ms/step - loss: 0.0564 - acc: 0.9780 - val_loss: 0.1024 - val_acc: 0.9653
# Epoch 24/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0723 - acc: 0.9744Epoch 00024: val_loss did not improve
# 352/352 [==============================] - 243s 691ms/step - loss: 0.0724 - acc: 0.9743 - val_loss: 0.0804 - val_acc: 0.9722
# Epoch 25/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0662 - acc: 0.9781Epoch 00025: val_loss did not improve
# 352/352 [==============================] - 243s 689ms/step - loss: 0.0661 - acc: 0.9782 - val_loss: 0.0669 - val_acc: 0.9739
# Epoch 26/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0572 - acc: 0.9806Epoch 00026: val_loss did not improve
# 352/352 [==============================] - 246s 700ms/step - loss: 0.0572 - acc: 0.9806 - val_loss: 0.0758 - val_acc: 0.9725
# Epoch 27/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0672 - acc: 0.9781Epoch 00027: val_loss did not improve
# 352/352 [==============================] - 245s 696ms/step - loss: 0.0671 - acc: 0.9782 - val_loss: 0.0762 - val_acc: 0.9739
# Epoch 28/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0644 - acc: 0.9765Epoch 00028: val_loss did not improve
# 352/352 [==============================] - 243s 689ms/step - loss: 0.0644 - acc: 0.9766 - val_loss: 0.0584 - val_acc: 0.9805
# Epoch 29/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0579 - acc: 0.9817Epoch 00029: val_loss did not improve
# 352/352 [==============================] - 245s 697ms/step - loss: 0.0583 - acc: 0.9815 - val_loss: 0.0948 - val_acc: 0.9682
# Epoch 30/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0504 - acc: 0.9818Epoch 00030: val_loss did not improve
#
# Epoch 00030: reducing learning rate to 0.001500000013038516.
# 352/352 [==============================] - 245s 696ms/step - loss: 0.0508 - acc: 0.9817 - val_loss: 0.0628 - val_acc: 0.9794
# Epoch 31/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0363 - acc: 0.9884Epoch 00031: val_loss improved from 0.05501 to 0.05187, saving model to inceptionV3_sgd.hdf5
# 352/352 [==============================] - 247s 702ms/step - loss: 0.0363 - acc: 0.9885 - val_loss: 0.0519 - val_acc: 0.9824
# Epoch 32/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0284 - acc: 0.9895Epoch 00032: val_loss improved from 0.05187 to 0.04642, saving model to inceptionV3_sgd.hdf5
# 352/352 [==============================] - 247s 702ms/step - loss: 0.0286 - acc: 0.9893 - val_loss: 0.0464 - val_acc: 0.9842
# Epoch 33/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0343 - acc: 0.9886Epoch 00033: val_loss did not improve
# 352/352 [==============================] - 245s 695ms/step - loss: 0.0342 - acc: 0.9886 - val_loss: 0.0468 - val_acc: 0.9834
# Epoch 34/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0334 - acc: 0.9881Epoch 00034: val_loss did not improve
# 352/352 [==============================] - 244s 692ms/step - loss: 0.0333 - acc: 0.9881 - val_loss: 0.0493 - val_acc: 0.9813
# Epoch 35/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0326 - acc: 0.9906Epoch 00035: val_loss improved from 0.04642 to 0.04491, saving model to inceptionV3_sgd.hdf5
# 352/352 [==============================] - 247s 701ms/step - loss: 0.0326 - acc: 0.9906 - val_loss: 0.0449 - val_acc: 0.9835
# Epoch 36/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0299 - acc: 0.9900Epoch 00036: val_loss did not improve
# 352/352 [==============================] - 246s 698ms/step - loss: 0.0298 - acc: 0.9901 - val_loss: 0.0509 - val_acc: 0.9803
# Epoch 37/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0352 - acc: 0.9879Epoch 00037: val_loss improved from 0.04491 to 0.03899, saving model to inceptionV3_sgd.hdf5
# 352/352 [==============================] - 245s 695ms/step - loss: 0.0352 - acc: 0.9879 - val_loss: 0.0390 - val_acc: 0.9851
# Epoch 38/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0258 - acc: 0.9909Epoch 00038: val_loss did not improve
# 352/352 [==============================] - 245s 695ms/step - loss: 0.0258 - acc: 0.9909 - val_loss: 0.0439 - val_acc: 0.9845
# Epoch 39/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0299 - acc: 0.9907Epoch 00039: val_loss did not improve
# 352/352 [==============================] - 245s 695ms/step - loss: 0.0298 - acc: 0.9908 - val_loss: 0.0423 - val_acc: 0.9866
# Epoch 40/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0285 - acc: 0.9909Epoch 00040: val_loss did not improve
# 352/352 [==============================] - 247s 702ms/step - loss: 0.0284 - acc: 0.9909 - val_loss: 0.0415 - val_acc: 0.9861
# Epoch 41/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0216 - acc: 0.9920Epoch 00041: val_loss improved from 0.03899 to 0.03756, saving model to inceptionV3_sgd.hdf5
# 352/352 [==============================] - 246s 698ms/step - loss: 0.0215 - acc: 0.9920 - val_loss: 0.0376 - val_acc: 0.9874
# Epoch 42/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0207 - acc: 0.9931Epoch 00042: val_loss did not improve
# 352/352 [==============================] - 245s 697ms/step - loss: 0.0209 - acc: 0.9929 - val_loss: 0.0410 - val_acc: 0.9864
# Epoch 43/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0172 - acc: 0.9936Epoch 00045: val_loss did not improve
# 352/352 [==============================] - 243s 690ms/step - loss: 0.0172 - acc: 0.9936 - val_loss: 0.0392 - val_acc: 0.9875
# Epoch 46/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0157 - acc: 0.9932Epoch 00046: val_loss improved from 0.03698 to 0.03399, saving model to inceptionV3_sgd.hdf5
# 352/352 [==============================] - 246s 700ms/step - loss: 0.0164 - acc: 0.9929 - val_loss: 0.0340 - val_acc: 0.9880
# Epoch 47/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0192 - acc: 0.9927Epoch 00047: val_loss did not improve
# 352/352 [==============================] - 246s 698ms/step - loss: 0.0192 - acc: 0.9927 - val_loss: 0.0380 - val_acc: 0.9863
# Epoch 48/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0187 - acc: 0.9948Epoch 00048: val_loss did not improve
# 352/352 [==============================] - 245s 697ms/step - loss: 0.0190 - acc: 0.9945 - val_loss: 0.0354 - val_acc: 0.9882
# Epoch 49/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0143 - acc: 0.9947Epoch 00049: val_loss did not improve
# 352/352 [==============================] - 248s 704ms/step - loss: 0.0142 - acc: 0.9947 - val_loss: 0.0376 - val_acc: 0.9875
# Epoch 50/50
# 351/352 [============================>.] - ETA: 0s - loss: 0.0140 - acc: 0.9950Epoch 00050: val_loss improved from 0.03399 to 0.03329, saving model to inceptionV3_sgd.hdf5
# 352/352 [==============================] - 245s 697ms/step - loss: 0.0139 - acc: 0.9950 - val_loss: 0.0333 - val_acc: 0.9885

# %% [markdown]
# ## 训练过程可视化

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('accuracy')
plt.xlabel('epoch')
plt.legend(['acc', 'val_acc'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper right')
plt.show()

# %%
plt.plot(history.history['lr'])
plt.title('Learning Rate')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## 预测测试集

# %%
y_pred = model.predict_generator(validate_gen, len(validate_gen),verbose=1,workers=20)
y_pred = np.argmax(y_pred, axis=1)
# Out:
# 391/391 [==============================] - 107s 274ms/step ETA:

# %%
def flatten_list(l):
    return [item for sublist in l for item in sublist]

y_true = flatten_list([np.argmax(y_true, axis=1) for x, y_true in validate_gen])

# %%
import pandas as pd
import seaborn as sn
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

confusion_table = confusion_matrix(y_true, y_pred)
confusion_table
# Out:
# array([[3028,   43],
#        [  32, 3153]])

# %% [markdown]
# ## 混淆矩阵

# %%
y_p=[]
y_t=[]
for var in (y_pred):
    if var>0:
        y_p.append(1)
    else:
        y_p.append(0)
for var in (y_true):
    if var>0:
        y_t.append(1)
    else:
        y_t.append(0)
c_table = confusion_matrix(y_t, y_p)
normalized_cf_matrix= c_table / c_table.sum(axis=1, keepdims=True)
df_cmx = pd.DataFrame(normalized_cf_matrix, index=[0, 1], columns=[0, 1])
plt.figure(figsize = (10,6))
sn.set(font_scale=1.5)
ax = sn.heatmap(df_cmx, annot=True, cmap='Oranges', fmt='.0%')
ax.set_ylabel('y_true')
ax.set_xlabel('y_pred')
plt.show()
